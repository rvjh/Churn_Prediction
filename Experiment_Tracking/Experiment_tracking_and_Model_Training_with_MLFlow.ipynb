# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_clean = pd.read_csv("../Clean_Input_Data/credit_card_churn_clean.csv")
df_clean
# Out:
#       Unnamed: 0  customer_id  customer_age gender  dependent_count  \
# 0              0    768805383            45      M                3
# 1              1    818770008            49      F                5
# 2              2    713982108            51      M                3
# 3              4    709106358            40      M                3
# 4              5    713061558            44      M                2
# ...          ...          ...           ...    ...              ...
# 7076       10120    710841183            54      M                1
# 7077       10121    713899383            56      F                1
# 7078       10122    772366833            50      M                2
# 7079       10124    716506083            44      F                1
# 7080       10126    714337233            43      F                2
#
#       education_level marital_status  income_category card_category  \
# 0                   1        married                2          blue
# 1                   2         single                0          blue
# 2                   2        married                3          blue
# 3                   0        married                2          blue
# 4                   2        married                1          blue
# ...               ...            ...              ...           ...
# 7076                1         single                2          blue
# 7077                2         single                0          blue
# 7078                2         single                1          blue
# 7079                1        married                0          blue
# 7080                2        married                0        silver
#
#       months_on_book  total_relationship_count  credit_limit  \
# 0                 39                         5       12691.0
# 1                 44                         6        8256.0
# 2                 36                         4        3418.0
# 3                 21                         5        4716.0
# 4                 36                         3        4010.0
# ...              ...                       ...           ...
# 7076              34                         5       13940.0
# 7077              50                         4        3688.0
# 7078              40                         3        4003.0
# 7079              36                         5        5409.0
# 7080              25                         6       10388.0
#
#       total_revolving_bal  active_customer
# 0                     777             True
# 1                     864             True
# 2                       0             True
# 3                       0             True
# 4                    1247             True
# ...                   ...              ...
# 7076                 2109             True
# 7077                  606             True
# 7078                 1851             True
# 7079                    0            False
# 7080                 1961            False
#
# [7081 rows x 14 columns]

# %% [markdown]
# # Split data

# %%
from sklearn.model_selection import train_test_split

def split_dataFrame(df_to_split, y_column):
    df_full_train, df_test = train_test_split(df_to_split, test_size=0.2, random_state=11)
    df_train,  df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

    df_full_train = df_full_train.reset_index(drop=True)
    df_train = df_train.reset_index(drop=True)
    df_val = df_val.reset_index(drop=True)
    df_test = df_test.reset_index(drop=True)

    y_full_train = df_full_train[y_column]
    y_train = df_train[y_column]
    y_val = df_val[y_column]
    y_test = df_test[y_column]


    del df_full_train[y_column]
    del df_train[y_column]
    del df_val[y_column]
    del df_test[y_column]

    # with pd.option_context('display.max_rows', 2, 'display.max_columns', None): 
    #     display(df_test)   

    print("df_to_split length: ", len(df_to_split))
    print()
    print("df_full_train length: ", len(df_full_train))
    print("df_train length: ", len(df_train))
    print("df_val length: ", len(df_val))
    print("df_test length: ", len(df_test))
    print()
    print("y_full_train length: ", len(y_full_train))
    print("y_train length: ", len(y_train))
    print("y_val length: ", len(y_val))
    print("y_test length: ", len(y_test))
    
    return df_full_train, df_train, df_val, df_test, y_full_train, y_train, y_val, y_test

# %%
y_column = "active_customer"
train_columns = ["customer_age", "gender", "dependent_count", "education_level", "marital_status", "income_category", "card_category", "months_on_book", "total_relationship_count", "credit_limit", "total_revolving_bal"]

df_full_train, df_train, df_val, df_test, y_full_train, y_train, y_val, y_test = split_dataFrame(df_clean[train_columns+[y_column]], y_column)
df_train
# Out:
# df_to_split length:  7081
#
# df_full_train length:  5664
# df_train length:  4248
# df_val length:  1416
# df_test length:  1417
#
# y_full_train length:  5664
# y_train length:  4248
# y_val length:  1416
# y_test length:  1417
#       customer_age gender  dependent_count  education_level marital_status  \
# 0               41      F                4                2         single
# 1               51      M                2                0        married
# 2               47      M                5                1        married
# 3               53      M                2                2        married
# 4               40      M                4                1        married
# ...            ...    ...              ...              ...            ...
# 4243            46      M                3                3        married
# 4244            44      M                2                0       divorced
# 4245            51      M                0                2        married
# 4246            48      F                3                3       divorced
# 4247            58      M                3                1         single
#
#       income_category card_category  months_on_book  total_relationship_count  \
# 0                   0          blue              26                         5
# 1                   2          blue              40                         2
# 2                   3          blue              37                         2
# 3                   2          blue              38                         6
# 4                   2          blue              36                         6
# ...               ...           ...             ...                       ...
# 4243                2          blue              39                         3
# 4244                2          blue              34                         6
# 4245                3          blue              40                         4
# 4246                1          blue              41                         4
# 4247                3          blue              51                         2
#
#       credit_limit  total_revolving_bal
# 0           1783.0                 1282
# 1           3559.0                    0
# 2           9410.0                    0
# 3           7928.0                 1228
# 4           5797.0                 1779
# ...            ...                  ...
# 4243       13344.0                 1907
# 4244        3650.0                 1270
# 4245        7158.0                    0
# 4246        9336.0                 1672
# 4247       10021.0                 1952
#
# [4248 rows x 11 columns]

# %% [markdown]
# ## Model training with XGboost

# %%
import xgboost as xgb
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score

def train(dataFrame, y, max_depth, eta):
    # Hot Encoding
    dicts = dataFrame.to_dict(orient="records")
    dv = DictVectorizer(sparse=False)
    X = dv.fit_transform(dicts)
    features = dv.get_feature_names_out()
    dtrain = xgb.DMatrix(X, label=y, feature_names=features)

    # train
    xgb_params = {
        'eta': eta,
        'max_depth': max_depth,
        'min_child_weight': 1,
        'objective': 'reg:squarederror',
        'nthread': 8,
        'seed':1,
        'verbosity':0
    }
    model = xgb.train(xgb_params, dtrain, num_boost_round=10)
    return dv, model

dv, model = train(df_train, y_train, 6, 0.3)

# %%
def predict(dataFrame, dv, model):
    dicts = dataFrame.to_dict(orient="records")
    X = dv.transform(dicts)
    features = dv.get_feature_names_out()
    dval = xgb.DMatrix(X, feature_names=features)
    y_pred = model.predict(dval)
    return y_pred, X


y_pred_val, X_val = predict(df_val, dv, model)
df_pred_val_result = df_val.copy()
df_pred_val_result['y_pred'] = y_pred_val
df_pred_val_result['y_pred_bool'] = df_pred_val_result['y_pred']>0.5
df_pred_val_result['y_val'] = y_val
df_pred_val_result
# Out:
#       customer_age gender  dependent_count  education_level marital_status  \
# 0               62      F                1                2         single
# 1               49      F                3                1        married
# 2               45      M                4                2        married
# 3               52      M                1                2        married
# 4               42      F                4                2         single
# ...            ...    ...              ...              ...            ...
# 1411            57      F                1                0         single
# 1412            38      M                2                2        married
# 1413            50      M                2                2        married
# 1414            59      F                1                2         single
# 1415            48      F                3                1        married
#
#       income_category card_category  months_on_book  total_relationship_count  \
# 0                   0          blue              56                         1
# 1                   0          blue              45                         3
# 2                   4          blue              36                         5
# 3                   2          blue              43                         3
# 4                   0          blue              36                         6
# ...               ...           ...             ...                       ...
# 1411                0          blue              46                         2
# 1412                3          blue              29                         5
# 1413                4          blue              43                         3
# 1414                0          blue              39                         5
# 1415                0          blue              36                         4
#
#       credit_limit  total_revolving_bal    y_pred  y_pred_bool  y_val
# 0           3109.0                    0  0.266958        False  False
# 1           1438.3                  726  0.859267         True   True
# 2          34516.0                  880  0.964725         True   True
# 3           7187.0                 2014  0.929658         True   True
# 4           2803.0                    0  0.696427         True  False
# ...            ...                  ...       ...          ...    ...
# 1411        9129.0                    0  0.472798        False  False
# 1412        7535.0                 2517  0.873151         True   True
# 1413       20114.0                    0  0.659105         True   True
# 1414        4404.0                 2272  0.944803         True   True
# 1415        3716.0                    0  0.668336         True   True
#
# [1416 rows x 14 columns]

# %%
# MAE, MSE, RMSE

from sklearn import metrics
import numpy as np
import pandas as pd

df_pred = pd.DataFrame(y_pred_val, columns=["predicted_months_on_book"])

mae = metrics.mean_absolute_error(y_val, y_pred_val)
mse = metrics.mean_squared_error(y_val, y_pred_val)
rmse = np.sqrt(metrics.mean_squared_error(y_val, y_pred_val))

print("MAE for numerical linear:", mae)
print("MSE for numerical linear:", mse)
print("RMSE for numerical linear:", rmse)
# Out:
# MAE for numerical linear: 0.21851909
# MSE for numerical linear: 0.11331143
# RMSE for numerical linear: 0.33661765

# %%
import matplotlib.pyplot as plt
from sklearn import metrics

thresholds = np.linspace(0, 1, 21)
y_count = len(df_pred.predicted_months_on_book)

scores = []
for t in thresholds:
    dev_within_t = (abs(y_pred_val-y_val) < t).sum()
    score = (dev_within_t*100)/y_count
    scores.append(score)
    print('Model max deviation +/-%.2f: %.3f percent' % (t, score))

plt.xlabel('thresholds')
plt.ylabel('% within deviation')
plt.title('% by delivetion error')
plt.plot(thresholds, scores)
# Out:
# Model max deviation +/-0.00: 0.000 percent
# Model max deviation +/-0.05: 31.073 percent
# Model max deviation +/-0.10: 54.308 percent
# Model max deviation +/-0.15: 61.299 percent
# Model max deviation +/-0.20: 65.325 percent
# Model max deviation +/-0.25: 69.350 percent
# Model max deviation +/-0.30: 73.376 percent
# Model max deviation +/-0.35: 76.695 percent
# Model max deviation +/-0.40: 80.085 percent
# Model max deviation +/-0.45: 82.627 percent
# Model max deviation +/-0.50: 84.534 percent
# Model max deviation +/-0.55: 85.946 percent
# Model max deviation +/-0.60: 88.206 percent
# Model max deviation +/-0.65: 89.901 percent
# Model max deviation +/-0.70: 91.172 percent
# Model max deviation +/-0.75: 92.726 percent
# Model max deviation +/-0.80: 94.633 percent
# Model max deviation +/-0.85: 95.904 percent
# Model max deviation +/-0.90: 97.034 percent
# Model max deviation +/-0.95: 98.517 percent
# Model max deviation +/-1.00: 99.929 percent

# %% [markdown]
# ##  Train model and sent to MLFlow

# %%
import os
import argparse
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
import mlflow
import pickle
from hyperopt import hp, space_eval
from hyperopt.pyll import scope
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType

# %%
import mlflow


## after configuring aws instance connection run this : 

mlflow.set_tracking_uri("http://15.207.72.49:5000")    ## instance created for mlops
mlflow.set_experiment('notebook-exp')
# Out:
# <Experiment: artifact_location='s3://mlops-s3-bucket-1/1', creation_time=1675198424200, experiment_id='1', last_update_time=1675198424200, lifecycle_stage='active', name='notebook-exp', tags={}>

# %%
mlflow.xgboost.autolog(disable=True)

xgb_params_search_space = {
    'max_depth': scope.int(hp.choice('max_depth', [5, 10, 12, 13, 14, 20,30,40,50,100])),
    'eta': scope.int(hp.choice('eta', [0, 0.001, 0.01, 0.1, 0.2, 0.3, 0.4, 0.6, 1, 2, 5, 10])),
    'min_child_weight': 1,
    'objective': 'reg:squarederror',
    'nthread': 8,
    'verbosity':0,
    "seed":42
}

# %%
def objective(params):
    with mlflow.start_run():
        active_mlflow_run_id = mlflow.active_run().info.run_id
        if (active_mlflow_run_id==None): raise ValueError("missing MLFlow active run.")
        print(f'Training model. Active MLFlow run_id: {active_mlflow_run_id}')
        mlflow.set_tag("model", "xgboost")

        dv = DictVectorizer(sparse=False)
        X_full_train = dv.fit_transform(df_full_train.to_dict(orient='records'))
        X_val = dv.transform(df_val.to_dict(orient='records'))
        features = dv.get_feature_names_out()
        dtrain = xgb.DMatrix(X_full_train, label=y_full_train.values, feature_names=features)
        dvalid = xgb.DMatrix(X_val, label=y_val.values, feature_names=features)

        booster = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=100,
            evals=[(dvalid, 'validation')],
            early_stopping_rounds=50
        )

        X_val = dv.transform(df_val.to_dict(orient='records'))
        dtrain = xgb.DMatrix(X_val, label=y_val.values, feature_names=features)
        y_pred_val = booster.predict(dvalid)

        rmse = np.sqrt(metrics.mean_squared_error(y_val, y_pred_val))
        mlflow.log_metric("rmse", rmse) 
        
        os.makedirs("models", exist_ok=True)
        
        with open("models/preprocessor.b","wb") as f_out:
            pickle.dump(dv,f_out)
        
        mlflow.log_artifact("models/preprocessor.b",artifact_path="preprocessor")
    
        mlflow.xgboost.log_model(booster,artifact_path="models_mlflow")
        print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
        

    return {'loss':rmse, 'status':STATUS_OK}

# %%
best_result = fmin(
    fn=objective,
    space=xgb_params_search_space,
    algo=tpe.suggest,
    max_evals=2,
    trials=Trials()
)
# Out:
# Training model. Active MLFlow run_id: 368b09e8e91f47918867ceb9b497e8c4
# [0]	validation-rmse:0.50460
# [1]	validation-rmse:0.49492
# [2]	validation-rmse:0.49996
# [3]	validation-rmse:0.48907
# [4]	validation-rmse:0.49317
# [5]	validation-rmse:0.48885
# [6]	validation-rmse:0.49068
# [7]	validation-rmse:0.48725
# [8]	validation-rmse:0.48878
# [9]	validation-rmse:0.48387
# [10]	validation-rmse:0.48750
# [11]	validation-rmse:0.47923
# [12]	validation-rmse:0.48514
# [13]	validation-rmse:0.47477
# [14]	validation-rmse:0.48201
# [15]	validation-rmse:0.47395
# [16]	validation-rmse:0.48108
# [17]	validation-rmse:0.46822
# [18]	validation-rmse:0.47559
# [19]	validation-rmse:0.46541
# [20]	validation-rmse:0.47540
# [21]	validation-rmse:0.46130
# [22]	validation-rmse:0.47424
# [23]	validation-rmse:0.45941
# [24]	validation-rmse:0.47027
# [25]	validation-rmse:0.45795
# [26]	validation-rmse:0.46824
# [27]	validation-rmse:0.45580
# [28]	validation-rmse:0.46718
# [29]	validation-rmse:0.45485
# [30]	validation-rmse:0.46310
# [31]	validation-rmse:0.45170
# [32]	validation-rmse:0.46356
# [33]	validation-rmse:0.44880
# [34]	validation-rmse:0.45821
# [35]	validation-rmse:0.44607
# [36]	validation-rmse:0.45489
# [37]	validation-rmse:0.44522
# [38]	validation-rmse:0.45621
# [39]	validation-rmse:0.44383
# [40]	validation-rmse:0.45109
# [41]	validation-rmse:0.44064
# [42]	validation-rmse:0.44597
# [43]	validation-rmse:0.44027
# [44]	validation-rmse:0.44354
# [45]	validation-rmse:0.43768
# [46]	validation-rmse:0.44350
# [47]	validation-rmse:0.43507
# [48]	validation-rmse:0.44194
# [49]	validation-rmse:0.43431
# [50]	validation-rmse:0.43937
# [51]	validation-rmse:0.43255
# [52]	validation-rmse:0.43824
# [53]	validation-rmse:0.43101
# [54]	validation-rmse:0.43645
# [55]	validation-rmse:0.42908
# [56]	validation-rmse:0.43504
# [57]	validation-rmse:0.42750
# [58]	validation-rmse:0.43229
# [59]	validation-rmse:0.42604
# [60]	validation-rmse:0.43029
# [61]	validation-rmse:0.42398
# [62]	validation-rmse:0.42832
# [63]	validation-rmse:0.42038
# [64]	validation-rmse:0.42656
# [65]	validation-rmse:0.41904
# [66]	validation-rmse:0.42382
# [67]	validation-rmse:0.41817
# [68]	validation-rmse:0.42279
# [69]	validation-rmse:0.41684
# [70]	validation-rmse:0.42091
# [71]	validation-rmse:0.41574
# [72]	validation-rmse:0.41992
# [73]	validation-rmse:0.41339
# [74]	validation-rmse:0.41763
# [75]	validation-rmse:0.41133
# [76]	validation-rmse:0.41576
# [77]	validation-rmse:0.41026
# [78]	validation-rmse:0.41451
# [79]	validation-rmse:0.40904
# [80]	validation-rmse:0.41263
# [81]	validation-rmse:0.40790
# [82]	validation-rmse:0.41146
# [83]	validation-rmse:0.40583
# [84]	validation-rmse:0.40998
# [85]	validation-rmse:0.40352
# [86]	validation-rmse:0.40794
# [87]	validation-rmse:0.40341
# [88]	validation-rmse:0.40610
# [89]	validation-rmse:0.40200
# [90]	validation-rmse:0.40404
# [91]	validation-rmse:0.40069
# [92]	validation-rmse:0.40273
# [93]	validation-rmse:0.39869
# [94]	validation-rmse:0.40192
# [95]	validation-rmse:0.39780
# [96]	validation-rmse:0.40035
# [97]	validation-rmse:0.39636
# [98]	validation-rmse:0.39877
# [99]	validation-rmse:0.39529
# default artifacts URI: 's3://mlops-s3-bucket-1/1/368b09e8e91f47918867ceb9b497e8c4/artifacts'
# Training model. Active MLFlow run_id: de0a9f14ea3f475984d6a265b3a93cbf
# [0]	validation-rmse:0.50000
# [1]	validation-rmse:0.50000
# [2]	validation-rmse:0.50000
# [3]	validation-rmse:0.50000
# [4]	validation-rmse:0.50000
# [5]	validation-rmse:0.50000
# [6]	validation-rmse:0.50000
# [7]	validation-rmse:0.50000
# [8]	validation-rmse:0.50000
# [9]	validation-rmse:0.50000
# [10]	validation-rmse:0.50000
# [11]	validation-rmse:0.50000
# [12]	validation-rmse:0.50000
# [13]	validation-rmse:0.50000
# [14]	validation-rmse:0.50000
# [15]	validation-rmse:0.50000
# [16]	validation-rmse:0.50000
# [17]	validation-rmse:0.50000
# [18]	validation-rmse:0.50000
# [19]	validation-rmse:0.50000
# [20]	validation-rmse:0.50000
# [21]	validation-rmse:0.50000
# [22]	validation-rmse:0.50000
# [23]	validation-rmse:0.50000
# [24]	validation-rmse:0.50000
# [25]	validation-rmse:0.50000
# [26]	validation-rmse:0.50000
# [27]	validation-rmse:0.50000
# [28]	validation-rmse:0.50000
# [29]	validation-rmse:0.50000
# [30]	validation-rmse:0.50000
# [31]	validation-rmse:0.50000
# [32]	validation-rmse:0.50000
# [33]	validation-rmse:0.50000
# [34]	validation-rmse:0.50000
# [35]	validation-rmse:0.50000
# [36]	validation-rmse:0.50000
# [37]	validation-rmse:0.50000
# [38]	validation-rmse:0.50000
# [39]	validation-rmse:0.50000
# [40]	validation-rmse:0.50000
# [41]	validation-rmse:0.50000
# [42]	validation-rmse:0.50000
# [43]	validation-rmse:0.50000
# [44]	validation-rmse:0.50000
# [45]	validation-rmse:0.50000
# [46]	validation-rmse:0.50000
# [47]	validation-rmse:0.50000
# [48]	validation-rmse:0.50000
# [49]	validation-rmse:0.50000
# [50]	validation-rmse:0.50000
# default artifacts URI: 's3://mlops-s3-bucket-1/1/de0a9f14ea3f475984d6a265b3a93cbf/artifacts'
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:43<00:00, 21.90s/trial, best loss: 0.3952893316745758]

# %% [markdown]
# ## Load model from MLFlow and predict once

# %%
import mlflow


RUN_ID = 'de0a9f14ea3f475984d6a265b3a93cbf'

logged_model = f's3://mlops-s3-bucket-1/1/{RUN_ID}/artifacts/models_mlflow'
# logged_model = f'runs:/{RUN_ID}/model'
model = mlflow.pyfunc.load_model(logged_model)

# %%
model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: de0a9f14ea3f475984d6a265b3a93cbf

# %%
## convering into xgboost model
xgboost_model = mlflow.xgboost.load_model(logged_model)

xgboost_model

# %%
with open('../Experiment_Tracking/models/preprocessor.b', 'rb') as f_in:
    dv_mlflow = pickle.load(f_in)

# %%
pred_dict = {"customer_age":100,"gender":"F","dependent_count":2,"education_level":2,"marital_status":"married","income_category":2,"card_category":"blue","months_on_book":6,"total_relationship_count":3,"credit_limit":float(4000),"total_revolving_bal":2500}


X = dv_mlflow.transform(pred_dict)
features = dv_mlflow.get_feature_names_out()
dpred = xgb.DMatrix(X, feature_names=features)
xgboost_model.predict(dpred)
# Out:
# array([0.5], dtype=float32)
